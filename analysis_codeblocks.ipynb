# %%
import pandas as pd
import matplotlib.pyplot as plt

'''
Copy the code blocks below, and just change the 
series name whenever you want to look at a new 
series in the data. Please be mindful of writing down 
which series you looked at for the given week, which 
ones you ignored, and which ones looked interesting enough
to discuss during standup. Feel free to work ahead, naturally! 
There's a lot of Series you can ignore. 

Series to ignore: 1. no data points, or minimal amount of data points 
                  2. you conducted time-series analysis and there's no meaningful changes
                     following a natural disaster 
                  3. Series with repeat data
                        Example: Towards the end of the csv files, you'll see that 
                                 there's some series analysis data about domestic violence.
                                 There's 5 of them, plus a series that combines the results. We'd only want the combination. 
                  4. Monetary? Only grab USD and percentages. 
                  
'''

puerto_rico_data = './puerto_rico_data.csv'
pr_df= pd.read_csv(puerto_rico_data)
pr_series = pr_df['Series Name'] == 'GDP growth (annual %)' # change series name 

japan_data = './japan_data.csv'
japan_df = pd.read_csv(japan_data)
japan_series = japan_df['Series Name'] == 'GDP growth (annual %)'  # change series name

# %%
# test for Puerto Rico DataFrame
print(pr_df)
# Out:
#          Series Code            Series Name Country Name Country Code  \
# 0  NY.GDP.MKTP.KD.ZG  GDP growth (annual %)  Puerto Rico          PRI
#
#        1990 [YR1990]     2000 [YR2000]      2014 [YR2014]      2015 [YR2015]  \
# 0  -2.84054072620241  3.27196452862317  -1.19036345385338  -1.04929003238674
#
#        2016 [YR2016]      2017 [YR2017]  ...     1969 [YR1969]  \
# 0  -1.26369434781117  -2.88521838398481  ...  9.37523403607574
#
#       1968 [YR1968]     1967 [YR1967]     1966 [YR1966]     1965 [YR1965]  \
# 0  5.18043459796691  6.22322335473204  7.49914839484343  9.20484246776418
#
#       1964 [YR1964]     1963 [YR1963]     1962 [YR1962]     1961 [YR1961]  \
# 0  7.06092371941381  8.65104701177735  8.32331253031427  7.04173846987173
#
#   1960 [YR1960]
# 0            ..
#
# [1 rows x 68 columns]

# %%
# test for Japan DataFrame 
print(japan_df)
# Out:
#              Series Name        Series Code Country Name Country Code  \
# 0  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG        Japan          JPN
#
#       1990 [YR1990]     2000 [YR2000]      2014 [YR2014]     2015 [YR2015]  \
# 0  4.84092905745234  2.76464755143648  0.296205514142628  1.56062669674904
#
#        2016 [YR2016]     2017 [YR2017]  ...     1969 [YR1969]  \
# 0  0.753826745903538  1.67533175166503  ...  12.4778945144972
#
#       1968 [YR1968]     1967 [YR1967]     1966 [YR1966]     1965 [YR1965]  \
# 0  12.8824681383236  11.0821423246927  10.6385615591626  5.81970787298272
#
#       1964 [YR1964]     1963 [YR1963]     1962 [YR1962]     1961 [YR1961]  \
# 0  11.6767081963981  8.47364238279388  8.90897299558067  12.0435364080117
#
#   1960 [YR1960]
# 0            ..
#
# [1 rows x 68 columns]

# %%
''' EXAMPLE ANALYSIS BASED ON LAURA'S WORK FOR PART #2
    THIS ONE IS FOR PUERTO RICO AND GDP GROWTH.

We decided that GDP Growth (%) wasn't an interesting series. 
There is no effect after Hurricane Maria (2017) as GDP 
was already falling before that.  There's some spikes, but 
notice that they're all within 0 and 1 on either side. 
There's a spike towards 2022, but that's when the economy got 
red hot in the US post-covid. Not a lot going on here. 

It is expected that you make similar analysis for your series. 


'''
# Out:
# " EXAMPLE ANALYSIS BASED ON LAURA'S WORK FOR PART #2\n    THIS ONE IS FOR PUERTO RICO AND GDP GROWTH.\n\nWe decided that GDP Growth (%) wasn't an interesting series. \nThere is no effect after Hurricane Maria (2017) as GDP \nwas already falling before that.  There's some spikes, but \nnotice that they're all within 0 and 1 on either side. \nThere's a spike towards 2022, but that's when the economy got \nred hot in the US post-covid. Not a lot going on here. \n\nIt is expected that you make similar analysis for your series. \n\n\n"
